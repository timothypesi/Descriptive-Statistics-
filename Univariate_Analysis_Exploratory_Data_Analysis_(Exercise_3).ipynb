# %% [markdown]
# # Exploratory Data Analysis: Univariate Analysis

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# > Which was the most improved SAT subject from the year 2017 - 2018?

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# ## 2. Reading the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Loading the Data from the source i.e. csv
# ---
url1 = 'http://bit.ly/SAT2017Dataset'
url2= 'http://bit.ly/SAT2018Dataset'
# ---
#
SAT2017 = pd.read_csv(url1)
SAT2017
SAT2018 = pd.read_csv(url2)
SAT2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %% [markdown]
# ## 3. Checking the Data

# %%
# Determining the no. of records in our dataset
#
SAT2017.shape[0]
SAT2018.shape[0]
# Out:
# 51

# %%
# Previewing the top of our dataset
SAT2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
SAT2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Previewing the bottom of our dataset
SAT2018.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
#     Total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %%
# Checking whether each column has an appropriate datatype
SAT2018['Participation'] = SAT2018['Participation'].str.replace('%','')
# Checking whether each column has an appropriate datatype
SAT2017['Participation'] = SAT2017['Participation'].str.replace('%','')

# %%
SAT2017['Participation'] = pd.to_numeric(SAT2017['Participation'])
SAT2018['Participation'] = pd.to_numeric(SAT2018['Participation'])

# %%
SAT2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     int64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## 4. External Data Source Validation

# %% [markdown]
# Making sure your data matches something outside of the dataset is very important. It allows you to ensure that the measurements are roughly in line with what they should be and it serves as a check on what other things might be wrong in your dataset. External validation can often be as simple as checking your data against a single number, as we will do here.
#
# An example would be suppose that you're working with a dataset on the population of countries during the year 2016. Validating such information with an external reliable resource such as World Bank Data would be important step to providing credibility to your dataset. Have a look at the following link for an example. [Link](https://rstudio-pubs-static.s3.amazonaws.com/182250_19977d0c5c06403fbad1e653850fc7c6.html).

# %% [markdown]
# ### a.Validation

# %% [markdown]
# ## 5. Tidying the Dataset

# %%
# Checking for Outliers
#


col_names = ['Participation', 'Evidence-Based Reading and Writing', 'Math']

fig, ax = plt.subplots(len(col_names), figsize=(10,20))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=SAT2017[col_val], ax=ax[i])
    ax[i].set_title('Box plot - ' + str(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
fig, ax = plt.subplots(len(col_names), figsize=(10,20))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=SAT2018[col_val], ax=ax[i])
    ax[i].set_title('Box plot - ' + str(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
# Checking for Anomalies
#
# Checking for Anomalies
# Checking for Outliers

#Function to remove outliers using z-score
def remove_outliers(data, col):
    col_upper = data[col].mean() + 3*data[col].std()
    col_lower = data[col].mean() - 3*data[col].std()
    df = data[(data[col]< col_upper) & (data[col]> col_lower)]
    return df 

# remove(dataset, 'Income')



for columns in col_names:

    SAT2017 = remove_outliers(SAT2017, columns)
    
SAT2017
# Out:
#                    State  Participation  Evidence-Based Reading and Writing  \
# 0                Alabama              5                                 593
# 1                 Alaska             38                                 547
# 2                Arizona             30                                 563
# 3               Arkansas              3                                 614
# 4             California             53                                 531
# 5               Colorado             11                                 606
# 6            Connecticut            100                                 530
# 7               Delaware            100                                 503
# 8   District of Columbia            100                                 482
# 9                Florida             83                                 520
# 10               Georgia             61                                 535
# ...

# %%
#Function to remove outliers using z-score
def remove_outliers(data, col):
    col_upper = data[col].mean() + 3*data[col].std()
    col_lower = data[col].mean() - 3*data[col].std()
    df = data[(data[col]< col_upper) & (data[col]> col_lower)]
    return df 

# remove(dataset, 'Income')



for columns in col_names:

    SAT2018 = remove_outliers(SAT2018, columns)
    
SAT2018['MEAN'] = SAT2018.T
# Out:
#                                          0       1        2         3   \
# State                               Alabama  Alaska  Arizona  Arkansas
# Participation                             6      43       29         5
# Evidence-Based Reading and Writing      595     562      577       592
# Math                                    571     544      572       576
# Total                                  1166    1106     1149      1169
#
#                                             4         5            6   \
# State                               California  Colorado  Connecticut
# Participation                               60       100          100
# Evidence-Based Reading and Writing         540       519          535
# Math                                       536       506          519
# Total                                     1076      1025         1053
#
#                                           7                     8        9   \
# ...

# %%
SAT2018_NEW =  SAT2018.set_index('State').T
SAT2018_NEW['Mean'] = SAT2018_NEW.mean()

# %%
SAT2018_NEW
# Out:
# State                               Alabama  Alaska  Arizona  Arkansas  \
# Participation                             6      43       29         5
# Evidence-Based Reading and Writing      595     562      577       592
# Math                                    571     544      572       576
# Total                                  1166    1106     1149      1169
#
# State                               California  Colorado  Connecticut  \
# Participation                               60       100          100
# Evidence-Based Reading and Writing         540       519          535
# Math                                       536       506          519
# Total                                     1076      1025         1053
#
# State                               Delaware  District of Columbia  Florida  \
# Participation                            100                    92       56
# Evidence-Based Reading and Writing       505                   497      550
# ...

# %%
# Identifying the Missing Data
SAT = pd.merge(SAT2017, SAT2018, on=['State'], how='left')

# %%
# Dealing with the Missing Data
SAT
# Out:
#                    State  Participation_x  \
# 0                Alabama                5
# 1                 Alaska               38
# 2                Arizona               30
# 3               Arkansas                3
# 4             California               53
# 5               Colorado               11
# 6            Connecticut              100
# 7               Delaware              100
# 8   District of Columbia              100
# 9                Florida               83
# 10               Georgia               61
# 11                Hawaii               55
# 12                 Idaho               93
# 13              Illinois                9
# 14               Indiana               63
# 15                  Iowa                2
# 16                Kansas                4
# 17              Kentucky                4
# 18             Louisiana                4
# 19                 Maine               95
# 20         Massachusetts               76
# ...

# %%
# More data cleaning procedures

# %% [markdown]
# ## 6. Exploratory Analysis

# %%
# Ploting the univariate summaries and recording our observations
#

# %% [markdown]
# ## 7. Implementing the Solution

# %%
# Implementing the Solution
#

# %% [markdown]
# ## 8. Challenging the solution

# %% [markdown]
# > The easy solution is nice because it is, well, easy, but you should never allow those results to hold the day. You should always be thinking of ways to challenge the results, especially if those results comport with your prior expectation.

# %%
# Reviewing the Solution 
#

# %% [markdown]
# ## 9. Follow up questions

# %% [markdown]
# > At this point, we can refine our question or collect new data, all in an iterative process to get at the truth.

# %% [markdown]
# ### a). Did we have the right data?

# %% [markdown]
# ### b). Do we need other data to answer our question?

# %% [markdown]
# ### c). Did we have the right question?
