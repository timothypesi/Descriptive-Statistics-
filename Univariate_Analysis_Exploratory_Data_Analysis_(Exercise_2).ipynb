# %% [markdown]
# # Exploratory Data Analysis: Univariate Analysis

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analytic Question

# %% [markdown]
# > Which subject performed best during the 2017 ACT test?

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# ## 2. Reading the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Loading the Data from the source 
# ---
url = 'http://bit.ly/2017ACTScoresDataset'
# ---
subject = pd.read_csv(url)
subject
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# ## 3. Checking the Data

# %%
# Determining the no. of records in our dataset
subject.shape[0]
# Out:
# 52

# %%
# Previewing the top of our dataset
subject.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Previewing the bottom of our dataset
subject.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
# Checking whether each column has an appropriate datatype
subject.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
subject['Composite']=subject['Composite'].str.replace('x','')#.str.replace('23.8','1.2')

# %%
subject['Composite'] = subject['Composite'].astype(float, errors = 'raise')

# %% [markdown]
# ## 4. External Data Source Validation

# %% [markdown]
# Making sure your data matches something outside of the dataset is very important. It allows you to ensure that the measurements are roughly in line with what they should be and it serves as a check on what other things might be wrong in your dataset. External validation can often be as simple as checking your data against a single number, as we will do here.
#
# An example would be suppose that you're working with a dataset on the population of countries during the year 2016. Validating such information with an external reliable resource such as World Bank Data would be important step to providing credibility to your dataset. Have a look at the following link for an example. [Link](https://rstudio-pubs-static.s3.amazonaws.com/182250_19977d0c5c06403fbad1e653850fc7c6.html).

# %% [markdown]
# ### a.Validation

# %% [markdown]
# ## 5. Tidying the Dataset

# %%
# Checking for Outliers

subject.columns

col_names = ['English', 'Math', 'Reading', 'Science','Composite' ]

fig, ax = plt.subplots(len(col_names), figsize=(10,20))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=subject[col_val], ax=ax[i])
    ax[i].set_title('Box plot - ' + str(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
# Checking for Anomalies
# Checking for Outliers

#Function to remove outliers using z-score
def remove_outliers(data, col):
    col_upper = data[col].mean() + 3*data[col].std()
    col_lower = data[col].mean() - 3*data[col].std()
    df = data[(data[col]< col_upper) & (data[col]> col_lower)]
    return df 

# remove(dataset, 'Income')



for columns in col_names:

    new_subject = remove_outliers(subject, columns)
    
new_subject
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
# Identifying the Missing Data
subject.isnull().any()
# Out:
# State            False
# Participation    False
# English          False
# Math             False
# Reading          False
# Science          False
# Composite        False
# dtype: bool

# %%
# Dealing with the Missing Data
#

# %%
# More data cleaning procedures
#

# %% [markdown]
# ## 6. Exploratory Analysis

# %%
# Ploting the univariate summaries and recording our observations
#
col_names = ['English', 'Math', 'Reading', 'Science','Composite' ]
subjects_mean = 
def plot_hist(data, col, bins, xlabel, ylable,title):
    plt.hist(data[col], bins = bins, rwidth=0.9)
    plt.xlabel(xlabel)
    plt.ylabel(ylable)
    plt.title(title)
    plt.show()
    
plot_hist(subject, 'Age', 10, 'Ages', 'number','Age distributions')

# %%
subject_mean = subject[['English', 'Math', 'Reading', 'Science', 'Composite']].mean()
print(subject_mean)
labels = ['English', 'Math', 'Reading', 'Science', 'Composite']
explode = (0.1, 0, 0, 0, 0)  
color = ['gold', 'green', 'blue', 'red', 'grey']

plt.pie(subject_mean, explode=explode, labels = labels, colors=color, autopct = '%1.1f%%', shadow = True, startangle = 140)


plt.axis('equal')
plt.title('Overal Subject Perfomance')
# Out:
# English      20.919231
# Math         21.173077
# Reading      22.001923
# Science      21.040385
# Composite    21.509615
# dtype: float64
# Text(0.5, 1.0, 'Overal Subject Perfomance')

# %% [markdown]
# ## 7. Implementing the Solution

# %%
# Implementing the Solution
#

# %% [markdown]
# ## 8. Challenging the solution

# %% [markdown]
# > The easy solution is nice because it is, well, easy, but you should never allow those results to hold the day. You should always be thinking of ways to challenge the results, especially if those results comport with your prior expectation.

# %%
# Reviewing the Solution 
#

# %% [markdown]
# ## 9. Follow up questions

# %% [markdown]
# > At this point, we can refine our question or collect new data, all in an iterative process to get at the truth.

# %% [markdown]
# ### a). Did we have the right data?

# %% [markdown]
# ### b). Do we need other data to answer our question?

# %% [markdown]
# ### c). Did we have the right question?
